# %%
import pandas as pd
from PycalcAct.dataset import FromLegendFileCSV


df1 = pd.read_csv("../data/calciumBound.csv", header=None)
df2 = pd.read_csv("../data/calciumFree.csv", header=None)

# file = FromLegendFileCSV("../data/legend.csv")
# df1 = df1[file.filter]
# df2 = df2[file.filter]

# %%
df1.shape, df2.shape
# Out:
# ((64507, 120), (64507, 120))

# %%
df1["feature"] = "calciumBound"
df2["feature"] = "calciumFree"

df4 = pd.merge(df1, df2, how="outer")
df4
# Out:
#                0          1          2          3          4          5  \
# 0       4.485388  59.341961  61.001725  59.632641  62.175765  63.495725
# 1       4.738958   6.076087   5.690707   4.966859   2.998264   8.113186
# 2       5.497785  29.412895  30.988674  29.165361  29.373484  31.192707
# 3       5.630780  12.898516   7.155942   8.205392  23.283810  20.111929
# 4       5.706580   4.520876   6.344773   4.721100   4.071171   5.407269
# ...          ...        ...        ...        ...        ...        ...
# 129009       NaN        NaN        NaN        NaN        NaN        NaN
# 129010       NaN        NaN        NaN        NaN        NaN        NaN
# 129011       NaN        NaN        NaN        NaN        NaN        NaN
# 129012       NaN        NaN        NaN        NaN        NaN        NaN
# 129013       NaN        NaN        NaN        NaN        NaN        NaN
#
#                 6          7          8          9  ...         111  \
# ...

# %%
df1.iloc[:, 1]
# Out:
# 0        27.122993
# 1        37.997206
# 2        58.994067
# 3        40.409519
# 4        70.312356
#            ...
# 64502          NaN
# 64503          NaN
# 64504          NaN
# 64505          NaN
# 64506          NaN
# Name: 1, Length: 64507, dtype: float64

# %%
df1 = pd.read_csv("../data/calciumBound.csv", header=None)
df2 = pd.read_csv("../data/calciumFree.csv", header=None)


print("Common rows:", (df1 == df2).all(axis=1).sum())
(df1 == df2).all(axis=1)
# Out:
# Common rows: 0
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64502    False
# 64503    False
# 64504    False
# 64505    False
# 64506    False
# Length: 64507, dtype: bool

# %%
(df1 == df2).all(axis=1)
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 64502    False
# 64503    False
# 64504    False
# 64505    False
# 64506    False
# Length: 64507, dtype: bool

# %%
df1.index[(df1 == df2).all(axis=1)]
# Out:
# Index([], dtype='int64')
